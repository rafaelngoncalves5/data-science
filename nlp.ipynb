# %%
# Mineração de textos
import matplotlib.pyplot as plt
import nltk
# nltk.download()
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
from matplotlib.colors import ListedColormap
from wordcloud import WordCloud
# conda install -c conda-forge wordcloud -> executar no Anaconda Prompt
import string

# %%
# Criação de um corpus lendo textos do disco
corpus = PlaintextCorpusReader('Arquivos', '.*', encoding='ISO-8859-1')

# %%
# Leitura dos arquivos de disco, percorrer os registros e mostrar o nome dos primeiros 100 arquivos
arquivos = corpus.fileids()
arquivos[0]
# Out:
# '1.txt'

# %%
# Zero a 10
arquivos[0:10]
# Out:
# ['1.txt',
#  '10.txt',
#  '100.txt',
#  '1000.txt',
#  '1001.txt',
#  '1002.txt',
#  '1003.txt',
#  '1004.txt',
#  '1005.txt',
#  '1006.txt']

# %%
# Imprime todos os nomes
for a in arquivos:
    print(a)

# %%
# Acesso ao texto do primeiro arquivo
texto = corpus.raw('1.txt')
texto
# Out:
# "@relation 'Reuters-21578 Corn ModApte Train-weka.filters.unsupervised.attribute.NumericToBinary-weka.filters.unsupervised.instance.RemoveFolds-S0-N5-F1'\r\n"

# %%
# Acesso a todos as palavras de todos os arquivos do corpus
todo_texto = corpus.raw()

# %%
# Obtenção de todas as palavras do corpus e visualização da quantidade
palavras = corpus.words()
palavras[170]
# Out:
# 'dividend'

# %%
len(palavras)
# Out:
# 619424

# %%
# Obtemos as stopwords em inglês
stops = stopwords.words('english')
stops

# %%
# Definição das cores que serão utilizadas na nuvem de palavras
mapa_cores = ListedColormap(['orange','green','red','magenta'])
# Criação da nuvem de palavras com no máximo 100 palavras e utilizamos os stop words
nuvem = WordCloud(background_color='white',stopwords=stops,max_words=100)
# Criação e visualização da nuvem de palavras
nuvem.generate(todo_texto)
plt.imshow(nuvem)

# %%
# Criação de nova nuvem de palavras, removendo stop words
palavras_semstop = [p for p in palavras if p not in stops]
len(palavras_semstop)
# Out:
# 555712

# %%
# Remoção de pontuação, gerando uma lista sem stopwords e sem pontuação
palavras_sem_pontuacao = [p for p in palavras_semstop if p not in string.punctuation]
len(palavras_sem_pontuacao)
# Out:
# 492087

# %%
# Cálculo da frequência das palavras e visualização das mais comuns
frequencia = nltk.FreqDist(palavras_sem_pontuacao)
frequencia
# Out:
# FreqDist({'¸': 3886, 'said': 3398, '3': 2836, '0': 2728, 'mln': 2724, '1': 2321, 'vs': 2201, 'J': 2145, 'dlrs': 1946, '000': 1641, ...})

# %%
# Mais comuns
mais_comuns = frequencia.most_common(100)
mais_comuns
# Out:
# [('¸', 3886),
#  ('said', 3398),
#  ('3', 2836),
#  ('0', 2728),
#  ('mln', 2724),
#  ('1', 2321),
#  ('vs', 2201),
#  ('J', 2145),
#  ('dlrs', 1946),
#  ('000', 1641),
#  ('2', 1584),
#  ('txtPK', 1558),
#  ('&#', 1466),
#  (";',", 1432),
#  ('The', 1429),
#  ('U', 1422),
#  ('S', 1414),
#  ('PK', 1397),
#  ('cts', 1374),
#  ('\x00\x00\x00', 1318),
#  ('4', 1296),
#  ('lt', 1288),
#  ('5', 1274),
#  ('Reuter', 1214),
#  ('\x10', 1181),
#  ('pct', 1147),
#  ('6', 1117),
#  ('\x00', 1117),
#  ('8', 1111),
#  ('\x0f', 1087),
#  ('7', 1080),
#  ('\x14', 1072),
#  ('\x91', 1048),
#  ('\x08', 1041),
#  ('\x83', 1041),
#  ('9', 1039),
#  ('\x03', 1039),
#  ('\x9e', 995),
#  ('\x92', 993),
#  ('÷', 991),
#  ('\x06', 975),
#  ('\x05', 967),
#  ('\x8e', 963),
#  ('¶', 962),
#  ('\x1b', 962),
#  ('\x90', 960),
#  ('\x93', 960),
#  ('\x18', 949),
#  ('\x94', 945),
#  ('\x07', 945),
#  ('\x8b', 942),
#  ('\x8d', 941),
#  ('\x9a', 936),
#  ('±', 933),
#  ('\x0e', 929),
#  ('ï', 924),
#  ('A', 923),
#  ('\x1a', 922),
#  ('\x9d', 912),
#  ('´', 911),
#  ('\x16', 910),
#  ('\x81', 910),
#  ('»', 906),
#  ('\x82', 906),
#  ('\x9c', 898),
#  ('\x9b', 897),
#  ('¤', 897),
#  ('°', 886),
#  ('£', 886),
#  ('\x02', 882),
#  ('\x19', 880),
#  ('year', 878),
#  ('\x96', 878),
#  ('\x8f', 877),
#  ('\x8a', 877),
#  ('¬', 871),
#  ('\x01', 869),
#  ('\x89', 866),
#  ('®', 864),
#  ('\x17', 864),
#  ('¡', 859),
#  ('¨', 859),
#  ('\x84', 859),
#  ('·', 857),
#  ('\x87', 857),
#  ('\xad', 852),
#  ('\x99', 849),
#  ('\x7f', 847),
#  ('«', 844),
#  ('¢', 844),
#  ('©', 841),
#  ('×', 834),
#  ('\x95', 829),
#  ('¦', 827),
#  ('§', 826),
#  ('\x04', 823),
#  ('¥', 821),
#  ('\x13', 818),
#  ('V', 815),
#  ('\x86', 810)]
