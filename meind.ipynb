# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_excel('meind.xlsx', sheet_name='Sheet1')

# %%
df.head()
# Out:
#    Ano-Mês  Despesa com Pessoal (R$)
# 0  2024-11                  20200.00
# 1  2024-10                  29350.00
# 2  2024-09                  20700.00
# 3  2024-08                  22033.33
# 4  2024-07                  28254.84

# %%
plt.plot(df['Ano-Mês'], df['Despesa com Pessoal (R$)'], color='#DC5B57')
plt.show()

# %%
# Trendline
x = df['Ano-Mês']
y = df['Despesa com Pessoal (R$)']

slope, intercept = np.polyfit(x, y, 1)
trendline = np.polyval([slope,intercept], x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2 x = df['Ano-Mês']
#       3 y = df['Despesa com Pessoal (R$)'].astype('str')
# ----> 5 slope, intercept = np.polyfit(x, y, 1)
#       6 trendline = np.polyval([slope,intercept], x)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\polynomial.py:630, in polyfit(x, y, deg, rcond, full, w, cov)
#     455 """
#     456 Least squares polynomial fit.
#     457
#    (...)
#     627
#     628 """
#     629 order = int(deg) + 1
# --> 630 x = NX.asarray(x) + 0.0
#     631 y = NX.asarray(y) + 0.0
#     633 # check arguments.
#
# TypeError: can only concatenate str (not "float") to str
