# %%
# Random Forest
# Gera diversos modelos
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('Credit.csv')
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = df.iloc[:,0:20].values
classe = df.iloc[:,20].values

# %%
# Codificando os dados categóricos em numéricos
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:,3] = labelencoder.fit_transform(previsores[:,3])
previsores[:,5] = labelencoder.fit_transform(previsores[:,5])
previsores[:,6] = labelencoder.fit_transform(previsores[:,6])
previsores[:,8] = labelencoder.fit_transform(previsores[:,8])
previsores[:,9] = labelencoder.fit_transform(previsores[:,9])
previsores[:,11] = labelencoder.fit_transform(previsores[:,11])
previsores[:,13] = labelencoder.fit_transform(previsores[:,13])
previsores[:,14] = labelencoder.fit_transform(previsores[:,14])
previsores[:,16] = labelencoder.fit_transform(previsores[:,16])
previsores[:,18] = labelencoder.fit_transform(previsores[:,18])
previsores[:,19] = labelencoder.fit_transform(previsores[:,19])

# %%
x_treinamento,x_teste,y_treinamento,y_teste = train_test_split(
    previsores,
    classe,
    test_size=0.3,
    random_state=0
)

# %%
floresta = RandomForestClassifier(n_estimators=100) # n modelos
floresta.fit(x_treinamento,y_treinamento)
# Out:
# RandomForestClassifier()

# %%
floresta.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1149420905),
#  DecisionTreeClassifier(max_features='sqrt', random_state=891516875),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1343639943),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1275095567),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1484133552),
#  DecisionTreeClassifier(max_features='sqrt', random_state=608708173),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1314348774),
#  DecisionTreeClassifier(max_features='sqrt', random_state=119136393),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1060004179),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1996060817),
#  DecisionTreeClassifier(max_features='sqrt', random_state=584493115),
#  DecisionTreeClassifier(max_features='sqrt', random_state=180072514),
#  DecisionTreeClassifier(max_features='sqrt', random_state=890496898),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1311755067),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1510987860),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1685318584),
#  DecisionTreeClassifier(max_features='sqrt', random_state=218986921),
#  DecisionTreeClassifier(max_features='sqrt', random_state=856008604),
#  DecisionTreeClassifier(max_features='sqrt', random_state=809072102),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1054361137),
#  DecisionTreeClassifier(max_features='sqrt', random_state=639686456),
#  DecisionTreeClassifier(max_features='sqrt', random_state=166826169),
#  DecisionTreeClassifier(max_features='sqrt', random_state=622037149),
#  DecisionTreeClassifier(max_features='sqrt', random_state=299241886),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1778850948),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1761521043),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1883945623),
#  DecisionTreeClassifier(max_features='sqrt', random_state=707974705),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1541826896),
#  DecisionTreeClassifier(max_features='sqrt', random_state=320183673),
#  DecisionTreeClassifier(max_features='sqrt', random_state=669189522),
#  DecisionTreeClassifier(max_features='sqrt', random_state=436292862),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1424924644),
#  DecisionTreeClassifier(max_features='sqrt', random_state=330591812),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2002675464),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2041574470),
#  DecisionTreeClassifier(max_features='sqrt', random_state=539649165),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1434015390),
#  DecisionTreeClassifier(max_features='sqrt', random_state=458480323),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1069382022),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1873741733),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1858406726),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1866160029),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1054250755),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1461685566),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1662398264),
#  DecisionTreeClassifier(max_features='sqrt', random_state=687663060),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1082468510),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1077880313),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1910267691),
#  DecisionTreeClassifier(max_features='sqrt', random_state=637645409),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1992191185),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2014251836),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2069556083),
#  DecisionTreeClassifier(max_features='sqrt', random_state=814915143),
#  DecisionTreeClassifier(max_features='sqrt', random_state=416825695),
#  DecisionTreeClassifier(max_features='sqrt', random_state=394673233),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1510886485),
#  DecisionTreeClassifier(max_features='sqrt', random_state=616243790),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1378518969),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1219968668),
#  DecisionTreeClassifier(max_features='sqrt', random_state=96550701),
#  DecisionTreeClassifier(max_features='sqrt', random_state=929529148),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1596972999),
#  DecisionTreeClassifier(max_features='sqrt', random_state=43021179),
#  DecisionTreeClassifier(max_features='sqrt', random_state=703244895),
#  DecisionTreeClassifier(max_features='sqrt', random_state=531543545),
#  DecisionTreeClassifier(max_features='sqrt', random_state=308764011),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1401311225),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1413910929),
#  DecisionTreeClassifier(max_features='sqrt', random_state=432769178),
#  DecisionTreeClassifier(max_features='sqrt', random_state=470376484),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1349642716),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1880833344),
#  DecisionTreeClassifier(max_features='sqrt', random_state=675595791),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1612235917),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1666911599),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1159735942),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1731155093),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1718068240),
#  DecisionTreeClassifier(max_features='sqrt', random_state=427920680),
#  DecisionTreeClassifier(max_features='sqrt', random_state=973262792),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1980933710),
#  DecisionTreeClassifier(max_features='sqrt', random_state=995739376),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1807208627),
#  DecisionTreeClassifier(max_features='sqrt', random_state=958636376),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1844041768),
#  DecisionTreeClassifier(max_features='sqrt', random_state=988455780),
#  DecisionTreeClassifier(max_features='sqrt', random_state=363928336),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1384048233),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1021265222),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2037643709),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1460847875),
#  DecisionTreeClassifier(max_features='sqrt', random_state=700022434),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1803136799),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1737874436),
#  DecisionTreeClassifier(max_features='sqrt', random_state=967089756),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1027860106),
#  DecisionTreeClassifier(max_features='sqrt', random_state=371122996),
#  DecisionTreeClassifier(max_features='sqrt', random_state=79935690)]

# %%
previsoes = floresta.predict(x_teste)
confusao = confusion_matrix(y_teste,previsoes)
taxa_acerto = accuracy_score(y_teste,previsoes)
taxa_acerto
# Out:
# 0.78
